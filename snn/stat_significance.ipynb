# %%
import os

folders_baselines  = [os.path.join(os.getcwd(), "sider", "models"), os.path.join(os.getcwd(), "tox21", "models")]
folders_snn  = [os.path.join(os.getcwd(), "sider", "models"), os.path.join(os.getcwd(), "tox21", "models")]

data_names = ["ml_maccs_", "ml_maccs_morgan_", "ml_morgan_1024_", "ml_RDKit_1024_", "ml_RDKit_morgan_"]
tasks = ["Hepatobiliary Disorders", "SR-ARE"]
data_names = [prefix + tasks[i] for i, prefix in data_names]
print(data_names)
#for idx, folder in enumerate(folders):
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       5 data_names = ["ml_maccs_", "ml_maccs_morgan_", "ml_morgan_1024_", "ml_RDKit_1024_", "ml_RDKit_morgan_"]
#       6 tasks = ["Hepatobiliary Disorders", "SR-ARE"]
# ----> 7 data_names = [prefix + tasks[i] for i, prefix in data_names]
#       8 print(data_names)
#       9 #for idx, folder in enumerate(folders):
#
# Cell In[11], line 7, in <listcomp>(.0)
#       5 data_names = ["ml_maccs_", "ml_maccs_morgan_", "ml_morgan_1024_", "ml_RDKit_1024_", "ml_RDKit_morgan_"]
#       6 tasks = ["Hepatobiliary Disorders", "SR-ARE"]
# ----> 7 data_names = [prefix + tasks[i] for i, prefix in data_names]
#       8 print(data_names)
#       9 #for idx, folder in enumerate(folders):
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ### Results - SIDER

# %%
# 5 data representations
# MACCS | Morgan | RDKit | MACCS + Morgan | Morgan + RDKit
data_representations = ["MACCS", "Morgan", "RDKit", "MACCS + Morgan", "Morgan + RDKit"]
results_CSNN = [
    [
        0.708358209,
        0.7048387096774194,
        0.7112676056338029,
        0.7424875621890547,
        0.6902918403811793,
        0.6738137780424857,
        0.7555555555555556,
        0.6544715447154472,
        0.7412467111920664,
        0.6640796019900498,
        0.6982089552238807,
        0.6889952153110047,
        0.7099658428772352,
        0.7140162795314672,
        0.6728468899521531,
        0.6961446740858506,
        0.6722488038277511,
        0.6939303482587065,
        0.6910714285714284,
        0.7061298076923077,
        0.7394282310899344,
        0.6547619047619049,
        0.6578259995981515,
        0.7042925278219395,
        0.6968253968253969,
        0.6756243756243756,
        0.7050403225806451,
        0.7370906168374523,
        0.6894715692184047,
        0.7653654485049833,
    ],
    [
        0.6590049751243781,
        0.6834677419354839,
        0.6901408450704225,
        0.7198009950248756,
        0.7188802858844551,
        0.6601151479054993,
        0.6988095238095239,
        0.6766260162601626,
        0.7125075895567698,
        0.7091542288557213,
        0.6550248756218905,
        0.6860047846889952,
        0.652903355,
        0.6842366487988882,
        0.6409489633173844,
        0.6299682034976152,
        0.6248006379585328,
        0.7064676616915422,
        0.6567460317460317,
        0.7153445512820513,
        0.676990272,
        0.6595238095238095,
        0.6926863572433193,
        0.6975357710651827,
        0.6676587301587301,
        0.6946053946053945,
        0.6620967741935484,
        0.6704842274462528,
        0.6958006831424552,
        0.6920681063122922,
    ],
    [
from scipy.stats import shapiro
import numpy as np
# Compute Differences
# diff = results_CSNN - results_KNN
# stat, p = shapiro(diff)

for i, aucs in enumerate(results_CSNN):
    print(data_representations[i])
    if i == 4:
        for k, results in enumerate(results_baselines):
            diff = np.array(aucs) - np.array(results[i])
            stat, p_value = shapiro(diff)
            print(f"Shapiro-Wilk test p-value for {baseline_names[k]}: {p_value}")
# Out:
# Shapiro-Wilk test p-value for KNN: 0.6806337422423989
# Shapiro-Wilk test p-value for SVM: 0.6461760059290924
# Shapiro-Wilk test p-value for XGB: 0.33437624170802827
# Shapiro-Wilk test p-value for RF: 0.30348979063246895
# Shapiro-Wilk test p-value for MLP: 0.8441097189629676

# %%
from scipy.stats import ttest_rel
# Example: model_a and model_b are your lists of AUCs
#t_stat, p_value = ttest_rel(model_a, model_b)

for i, aucs in enumerate(results_CSNN):
    print(data_representations[i])
    if i == 4:
        for k, results in enumerate(results_baselines):
            diff = np.array(aucs) - np.array(results[i])
            stat, p_value = shapiro(diff)
            print(f"Shapiro-Wilk test p-value for {baseline_names[k]}: {p_value}")

# %% [markdown]
# ### Results - Tox21

# %%
# 5 data representations
# MACCS | Morgan | RDKit | MACCS + Morgan | Morgan + RDKit
data_representations = ["MACCS", "Morgan", "RDKit", "MACCS + Morgan", "Morgan + RDKit"]
results_CSNN = [
    [],
    [],
    [],
    [],
    [
        0.7099502487562189,
        0.7334677419354839,
        0.7253521126760564,
        0.7272636815920398,
        0.6918800873535835,
        0.6887035934087751,
        0.7125,
        0.619918699,
        0.7289010321797207,
        0.6632835820895523,
        0.693134328,
        0.6879984051036683,
        0.6561181434599157,
        0.6967440937065714,
        0.6824162679425837,
        0.6502384737678855,
        0.6870015948963317,
        0.6787064676616916,
        0.6690476190476191,
        0.7297676282051282,
        0.6617033948779035,
        0.6702380952380952,
        0.7004219409282701,
        0.6834260731319555,
        0.6912698412698413,
        0.688111888,
        0.6673387096774194,
        0.6942937512557766,
        0.699015471,
        0.709094684,
    ],
]
results_KNN = [
    [],
    [],
    [],
    [],
    [
        0.6507462686567164,
        0.7405241935483873,
        0.7183098591549295,
        0.7461691542288557,
        0.6738137780424855,
        0.7071669644629739,
        0.7595238095238096,
        0.6713414634146342,
        0.7352762598664239,
        0.6851741293532339,
        0.6993034825870647,
        0.6760366826156299,
        0.6322081575246132,
        0.6597180861623982,
        0.6507177033492823,
        0.6707074721780605,
        0.6901913875598086,
        0.7467661691542289,
        0.647420635,
        0.7548076923076923,
        0.7092515386142545,
        0.6841269841269842,
        0.7019288728149488,
        0.6595786963434023,
        0.7097222222222221,
        0.6198801198801198,
        0.6796370967741935,
        0.7478400642957606,
        0.6464737793851717,
        0.717607973,
    ],
]
results_SVM = [
    [],
    [],
    [],
    [],
    [
        0.6832835820895522,
        0.7110887096774193,
        0.7253521126760564,
